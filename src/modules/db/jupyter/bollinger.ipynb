# %%
import pandas as pd
import numpy as np

import plotly.graph_objects as go
import datetime

# %%
n225 = pd.read_csv("../data/1330.csv")
df = pd.read_csv("../data/2930.csv")
df = df.sort_values(by="Date")
df = df[df["Date"]>"2021-01-01"]

# %%
ma = pd.DataFrame()
ma['ma5'] = df['Close'].rolling(window=5).mean()
ma['ma15'] = df['Close'].rolling(window=15).mean()
ma['ma30'] = df['Close'].rolling(window=30).mean()

# %%
fig = go.Figure()
fig.add_trace(go.Candlestick(x = df['Date'], open=df['Open'],high=df['High'],low=df['Low'],close=df['Close']))
fig.add_trace(go.Scatter(x=df["Date"], y=ma["ma5"], mode='lines', name="Upper"))
fig.add_trace(go.Scatter(x=df["Date"], y=ma["ma30"], mode='lines', name="Lower"))


fig.show()
# Out:
# <div>                            <div id="9069ae0e-a156-4d0e-91f2-5734be1949a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9069ae0e-a156-4d0e-91f2-5734be1949a5")) {                    Plotly.newPlot(                        "9069ae0e-a156-4d0e-91f2-5734be1949a5",                        [{"close": [458.1, 456.1, 457.1, 461.09, 469.08, 468.08, 464.09, 466.08, 478.06, 478.06, 496.02, 519.98, 523.97, 527.96, 518.98, 521.97, 535.94, 567.88, 569.88, 573.87, 588.84, 596.82, 623.77, 611.79, 625.77, 616.78, 627.76, 646.73, 637.74, 636.74, 643.73, 639.74, 627.76, 634.75, 608.8, 619.0, 618.0, 638.0, 638.0, 643.0, 643.0, 645.0, 671.0, 646.0, 647.0, 655.0, 666.0, 662.0, 660.0, 662.0, 665.0, 664.0, 669.0, 665.0, 646.0, 655.0, 664.0, 670.0, 663.0, 637.0], "hig
# ...

# %%
param = pd.DataFrame()
param['mean'] = df['Close'].mean()
param['std'] = df['Close'].std()

param.head()
# Out:
# Empty DataFrame
# Columns: [mean, std]
# Index: []

# %%
df['Close'].mean()
# Out:
# 594.8468333333333

# %%
fig = go.Figure()
fig.add_trace(go.Candlestick(x = df['Date'], open=df['Open'],high=df['High'],low=df['Low'],close=df['Close']))
fig.add_trace(go.Scatter(x=df["Date"], y=bband["Upper"], mode='lines', name="Upper"))
fig.add_trace(go.Scatter(x=df["Date"], y=bband["Lower"], mode='lines', name="Lower"))


fig.show()
# Out:
# <div>                            <div id="c5288376-e033-44be-9f37-f61d26d91355" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5288376-e033-44be-9f37-f61d26d91355")) {                    Plotly.newPlot(                        "c5288376-e033-44be-9f37-f61d26d91355",                        [{"close": [458.1, 456.1, 457.1, 461.09, 469.08, 468.08, 464.09, 466.08, 478.06, 478.06, 496.02, 519.98, 523.97, 527.96, 518.98, 521.97, 535.94, 567.88, 569.88, 573.87, 588.84, 596.82, 623.77, 611.79, 625.77, 616.78, 627.76, 646.73, 637.74, 636.74, 643.73, 639.74, 627.76, 634.75, 608.8, 619.0, 618.0, 638.0, 638.0, 643.0, 643.0, 645.0, 671.0, 646.0, 647.0, 655.0, 666.0, 662.0, 660.0, 662.0, 665.0, 664.0, 669.0, 665.0, 646.0, 655.0, 664.0, 670.0, 663.0, 637.0], "hig
# ...
